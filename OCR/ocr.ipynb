# %% [markdown]
# import numpy as np
# from matplotlib.pyplot import imshow
# %matplotlib inline
#
# pil_im = Image.open('output.jpg', 'r')
# imshow(np.asarray(pil_im))

# %%
from PIL import Image
import pytesseract
from pdf2image import convert_from_path
import warnings
warnings.filterwarnings("ignore")

# %%
def pdftostring(path):
    pages = convert_from_path(path, 500)
    for i in range(len(pages)):
        pages[i].save('output.jpg', 'JPEG')
        try:
            text = pytesseract.image_to_string(Image.open('output.jpg'))
            print(text)
        except:
            pass

# %%
pdftostring('jays.pdf')
# Out:
# THE 2019 MASTERCLASS
#
# THREE STEPS TO CREATE A YEAR OF ZERO EXCUSES
#
#
#
# THE THREE PILLARS
#
# Ask yourself, "How comfortable will | feel if I'm
# sitting here one year from now and | haven't
# made any progress in my life?
#
# In 2019, you have a choice - you either keep
# making excuses If you're not progressing or you
# start making choices.
#
#
#
# 1. LEADER
# We will make excuses until we have someone that we can be accountable to.
#
# The tipping point in our accountability and personal growth occurs when we find
# a mentor or a coach.
#
# Add your notes here:
#
# JOIN THE GENIUS COMMUNITY TODAY!
#
# Monthly membership, live weekly coaching with Jay, full access to the entire
# Genius library including expert interviews and exclusive access to Genius
# meetups around the globe.
#
# Head to www.jayshetty.me/ offer to enrol.
#
# IM © JAY SHETTY 2019
# THE 2019 MASTERCLASS
#
# THREE STEPS TO CREATE A YEAR OF ZERO EXCUSES
#
#
#
# THE THREE PILLARS (CONT.)
#
# 2. THE LADDER PRINCIPLE
#
# The ladder principle lets you take immediate action with your goals.
#
# What is your one big goal for 2019?
#
# Below the goal, try and understand the process, For example, If your goal Is to
# write a book the next step in the process would be to research how to write a
# book and then speak to people who have written a book.
#
# Add the rungs in the ladder for your process below:
#
# IM © JAY SHETTY 2019
# THE THREE PILLARS (CONT.)
# 3. LOUDER
#
# At the third pillar, we want to amplify the change we are going to make by
# making the intention really loud and powerful. For example, make your excuses
# smaller and quieter by finding a group of people that will support you.
#
# Add your notes here:
#
# READY TO CHANGE YOUR LIFE?
#
# JOIN THE GENIUS COMMUNITY TODAY!
#
# For just over $1a day, you will have exclusive access to:
#
# e Live weekly coaching sessions with Jay.
#
#
#
#
# e Monthly Genius membership. 4
# e Full access to the entire Genius library F
# available on replay (including coaching -
# and expert interviews.) i
#
# p
# "i
#
# BONUSES included:
#
# e Jay's book notes.
#
# e Access to Jay's meditations.
#
# e Exclusive access to Genius meetups
# around the globe.
#
# e Access to all past content in the Genius
# library (Over 40 episodes of content)
#
# Head to www .jayshetty.me/ offer to enrol!
#
# AeA © JAY SHETTY 2019

# %%
def imagetostring(path):
    text = pytesseract.image_to_string(Image.open(path))
    print(text)

# %%
imagetostring('idCard.jpg')
from IPython.display import Image
Image(filename= 'idCard.jpg', width= 500, height= 250)
# Out:
# gy. NORTHERN INDIA ENGINEERING COLLEGE
#
# Affiliated to GGS Indraprastha University, Dethi
#
#
#
#
#
#
#
#
#
#
# (Approved by AICTE, Ministry of HRD, Got of India)
# FC-26, Shastri Park, New Delhi-110053 , Ph.: 011-39905900-99
#
# Enroliment No.: 00615603115
#
# Name :
# Course : B.Tech-IT
# DOB : 25/01/1996
#
# Father's Name :_ Mr. Sudhir Kumar Goel
# Phone No. : 7042548961,9818613834
# Address : 227, Ram Nagar, Ghaziabad,
#
# Uttar Pradesh-201001
# BloodGroup : AB+ ae”
# C.E.0.
